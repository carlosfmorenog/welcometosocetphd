# %% [markdown]
# # Welcome to your Research Degree!!

# %% [markdown]
# # Your Research Degree Coordinators

# %% [markdown]
# * Dr Carlos Moreno-Garcia (Computing), Office N428
#     * c.moreno-garcia@rgu.ac.uk

# %% [markdown]
# * Dr Taimoor Asim (Engineering), Office N428
#     * t.asim@rgu.ac.uk

# %% [markdown]
# * Dr Mohamed Amish (MRes), Office Space N447
#     * m.amish-e@rgu.ac.uk.ac.uk

# %% [markdown]
# * Shared Mailbox for all RDCs
#     * SOCET-RDC@rgu.ac.uk

# %% [markdown]
# * Shared Mailbox for office staff to deal with Research queries
#     * SOCET-ResearchAdmin@rgu.ac.uk
#     * Managed (mostly) by Lynne Brien

# %% [markdown]
# # Useful info

# %% [markdown]
# * [Academic Regulations for Research Degrees (A6)](https://www.rgu.ac.uk/about/governance/academic-governance/academic-regulations)

# %% [markdown]
# * [Research Degree Administration](https://liverguac.sharepoint.com/sites/PGRDMS)

# %% [markdown]
# * [SoCET Research Student Handbook](https://liverguac.sharepoint.com/teams/SoCET-ResearchStudents/SitePages/SOCET-Research-Student-Handbook.aspx)

# %% [markdown]
# * [SoCET-Research](https://teams.microsoft.com/l/team/19%3Ae8d952da3e9f4b0a91d1a4046e7486c6%40thread.skype/conversations?groupId=9dc38e60-3d95-4c53-88d4-09f6bae8220f&tenantId=51a0a69c-0e4f-4b3d-b642-12e013198635) Teams channel
#     * Has info on general announcements, funding, seminars & research groups

# %% [markdown]
# * [SoCET-ResearchStudents](https://teams.microsoft.com/l/team/19%3A8NQyQe4NsRt7hDFNUtX0Y5ZPMeDTW-7lNfX2MdRsEwc1%40thread.tacv2/conversations?groupId=2c275cdc-f795-4e48-99fa-4fec4fe206c1&tenantId=51a0a69c-0e4f-4b3d-b642-12e013198635) Teams channel
#     * Has info exclusive for you!

# %% [markdown]
# * Please send an email ASAP to ResearchAdmin if you cannot see these Teams!

# %% [markdown]
# * Your class reps: Akech Kuanyin Malang & Harini Sampath Kumar

# %% [markdown]
# # What is a PhD?

# %% [markdown]
# ![What is a PhD](https://www.dropbox.com/scl/fi/ycti4wbvo2zz8qpu1j270/ezgif-18c082182d8e20.gif?rlkey=jqtzcrkxywtvldh64b00609q0&raw=1)

# %% [markdown]
# # What is *NOT* a PhD?

# %% [markdown]
# * A project with a start and an end

# %% [markdown]
# * A project that addresses one particular problem or that can save a lot of money

# %% [markdown]
# * A personal milestone (or for grade inflation)

# %% [markdown]
# * I **STRONGLY** recommend you to read [this paper](https://arxiv.org/html/2402.08298v1) and [this post](https://ehudreiter.com/2025/11/24/hard-to-change-poor-research-culture/) to see what I mean!

# %% [markdown]
# # The (typical) PhD journey

# %% [markdown]
# ![PhD Timeline](https://www.dropbox.com/scl/fi/l7x4t57yqeclc23eo6vny/PhDTimeline.jpg?rlkey=9dr4skaocbcsgzvjdj7t1rstl&raw=1)

# %% [markdown]
# * MRes is just the first three months, and then on to the thesis write up and examination (Month 12-24)

# %% [markdown]
# # Paperwork!

# %% [markdown]
# ## Registration

# %% [markdown]
# * All the information on how to do your registration can be found [here](https://liverguac.sharepoint.com/sites/PGRDMS/SitePages/Student-Research-Degree-Forms.aspx#registration)
#     * There are many forms (or a unified one) but still, you need plenty of time for this!
#     * You have **3 months** to register!

# %% [markdown]
# ## Annual Review Meetings (aka RSR September-November)

# %% [markdown]
# * All students $\geq$6 months from registration

# %% [markdown]
# * You need to fill in the [Annual RSR form](https://liverguac.sharepoint.com/sites/PGRDMS/SitePages/Staff-Research-Degree-Forms.aspx#progress-monitoring) (part 1 and 2) and submit it using [this link](https://liverguac.sharepoint.com/:l:/s/PGRDMS/JAC-GKvvgyJPQo4V-Sy6mng8Aey_I4KYpTXX0E8MG3q7n1w?nav=YWI0ZGQ4Y2QtZTVlYi00MzQ5LTliNGYtY2NjM2EwMGJlZTgy)

# %% [markdown]
# * Then, your supervisor will get a notification to fill in part 3 and notify the RDCs about this

# %% [markdown]
# * After forms have been collected, you can schedule a meeting with your RDC/group lead for your RSR interview
#     * Who you do the meeting with and how to schedule it depends on the RDC
#     * This will be communicated when the time comes

# %% [markdown]
# ## Interim RSR Meetings (February)

# %% [markdown]
# * You only need to fill in the [Interim RSR Form](https://liverguac.sharepoint.com/sites/PGRDMS/SitePages/Student-Research-Degree-Forms.aspx#progress-monitoring) and [submit it](https://liverguac.sharepoint.com/sites/PGRDMS/_layouts/15/listforms.aspx?cid=ZWZhYjE4YmUtMjI4My00MjRmLThlMTUtZjkyY2JhOWE3ODNj&nav=YWI0ZGQ4Y2QtZTVlYi00MzQ5LTliNGYtY2NjM2EwMGJlZTgy) (no meeting unless there's risk)

# %% [markdown]
# ## Other docs
#
# All of them available [here](https://liverguac.sharepoint.com/sites/PGRDMS/SitePages/Research-Degree-Forms.aspx)
#
# * **RDT**: To declare yourself ready for the transfer viva
# * **RDS**: Change of supervisor (hope you never use it!)
#     * For some reason it is on the "staff side" but in fact it is only used by the student!
# * **RDInterrupt**: Break from studies (same!)
# * **RDDecl**: A declaration which you should add to your thesis when you submit it
# * **RDE**: Your supervisor uses this to nominate your examination team and viva date

# %% [markdown]
# # Computing Resources

# %% [markdown]
# * We've collated [a list](https://docs.google.com/spreadsheets/d/1fIuC2ZjWdG_j3O5KgArbbouuzkNYHtNa/edit?usp=drive_link&ouid=102964071366260899886&rtpof=true&sd=true) with some GPU and LLM providers!
#     * Also available in the SOCET-ResearchStudents tabs
#     * Feel free to add anything you know!

# %% [markdown]
# * Plus the DGX...

# %% [markdown]
# * **Don't** use Anaconda!
#     * unless you're teaching?!

# %% [markdown]
# * Speaking about LLMs...
#     * The Graduate School has a [very strict policy](https://teams.microsoft.com/l/channel/19%3A8NQyQe4NsRt7hDFNUtX0Y5ZPMeDTW-7lNfX2MdRsEwc1%40thread.tacv2/tab%3A%3A8c887cc4-59c0-4e73-a4b7-2da6415b7bfb?context=%7B%22channelId%22%3A%2219%3A8NQyQe4NsRt7hDFNUtX0Y5ZPMeDTW-7lNfX2MdRsEwc1%40thread.tacv2%22%7D&tenantId=51a0a69c-0e4f-4b3d-b642-12e013198635) on **not** using them for your PgCert reports and your thesis!
#     * Be sure you check the guidance on LLM usage if you are submitting a paper to a journal/conference

# %% [markdown]
# # Engineering Resources

# %% [markdown]
# ![Eng Resources](https://www.dropbox.com/scl/fi/9ekr5kaqfh55kwtnhl84q/engfacilities.png?rlkey=ekdzwjzvla3lkomqhtk0u7tyu&raw=1)

# %% [markdown]
# # Attendance

# %% [markdown]
# * Full-time students are expected to be on campus **AT LEAST** 3 days per week

# %% [markdown]
# * We will be checking this, as it is necessary for you to comply with your visa requirements

# %% [markdown]
# * We are aware that some of you have part-time jobs or other commitments
#     * Be honest about it!

# %% [markdown]
# # Supervisory Meetings

# %% [markdown]
# * **AT LEAST** once every two weeks

# %% [markdown]
# * **Supervisors** have to fill in this [form](https://forms.office.com/pages/responsepage.aspx?id=nKagUU8OPUu2QhLgExmGNWCOw52VPVNMiNQJ9rroIg9UOTlCVklKTjdVQjFFTFo0OTZBVTBSNURSQSQlQCN0PWcu&route=shorturl) after every meeting, but students are **encouraged** to send a weekly email to their supervisory team with their "side of the story" and keep a record!

# %% [markdown]
# # Spaces

# %% [markdown]
# * N436 and N536 are open plan hotdesking areas for all PGR students!

# %% [markdown]
# * Students shouldn't go into N447

# %% [markdown]
# * Be respectful in the hubs, no noise!
#     * There are **plenty** of rooms that can be booked for meetings! Email PGRBooking@rgu.ac.uk or SOCET-Timetabling@rgu.ac.uk to find out more about the rooms that can be used (and to reseve them!)

# %% [markdown]
# * You can even go to the Library and the [Student Union](https://www.rguunion.co.uk/spaces/) to work and meet!

# %% [markdown]
# # Research Culture

# %% [markdown]
# * Do you belong to a [research group](https://liverguac-my.sharepoint.com/:w:/g/personal/n_wiratunga_rgu_ac_uk/EXYHSfFAqnJMnykQqYckNG4BlRHbiDI8GYRfBm9vnS-j8Q?e=vlgA5g&CID=6D972D68-408D-4F67-BE83-A416679E54E4&wdLOR=c39E56115-BE33-4C3A-9C16-6479D869A1C8)?

# %% [markdown]
# * Do you know which [theme(s)](https://www.rgu.ac.uk/research/our-research-degrees/research-degree-themes) is your PhD lined up to?

# %% [markdown]
# * Are you aware of the [School Seminars](https://seminars.rgusocet.org/)?

# %% [markdown]
# * Do you know if there are any societies in Scotland, the UK or the world, that support your activities? e.g. [SICSA](https://www.sicsa.ac.uk/), [IEEE](https://www.ieee.org/), [SULSA](https://sulsa.ac.uk/), [SINAPSE](https://www.sinapse.ac.uk/), [SPIE](https://spie.org/#_=_), etc.

# %% [markdown]
# * By the way, the [SICSA Conference](https://sicsaconf.org/) has just been announced, I encourage all computing-related students to attend!

# %% [markdown]
# # Exposure
# This will be reviewed during your RSR meeting

# %% [markdown]
# * [Worktribe](https://rgu-research.worktribe.com/) and [OpenAir](https://rgu-repository.worktribe.com/)

# %% [markdown]
# * [Google Scholar](https://scholar.google.com/citations?user=G8DsySMAAAAJ)

# %% [markdown]
# * [ORCID](https://orcid.org/0000-0001-7218-9023)

# %% [markdown]
# * Other ways to disseminate your research (e.g. [personal website](https://cfmgcomputing.blogspot.com/p/home.html), [GitHub](https://github.com/RGU-Computing/Researcher-Contributions), [Social Media](https://www.linkedin.com/in/carlos-f-moreno-garcia/), etc.)

# %% [markdown]
# # Conferences and Journals

# %% [markdown]
# * Your supervisor is **usually** the one that guides you into which ones should be your **go to** journals and conferences

# %% [markdown]
# * However, you are free to explore as long as you keep in mind the quality of and the reputation of the outlet

# %% [markdown]
# * You should use ranking systems such as [JCR](https://jcr-clarivate-com.ezproxy.rgu.ac.uk/jcr/home?app=jcr&Init=Yes&authCode=null&SrcApp=IC2LS) and [SCIMAGO](https://www.scimagojr.com/journalrank.php) (journals) or [CORE](https://portal.core.edu.au/conf-ranks/) and [ConfRanks](http://www.conferenceranks.com/) (conferences) to inform your decision!

# %% [markdown]
# * For instance, in the Interactive Machine Vision Research Group we have a [shared document](https://liverguac.sharepoint.com/:x:/r/sites/CSDMWebProjects/_layouts/15/doc2.aspx?sourcedoc=%7B0C925038-8A55-460E-A5F4-50AADA14F34B%7D&file=IMV.xlsx&action=default&mobileredirect=true) where we keep track of journals and conferences that are relevant to us!

# %% [markdown]
# # Templates

# %% [markdown]
# * Forget about MS Word (and possibly even PowerPoint!), we have better tools to write

# %% [markdown]
# * Get into [LaTeX](https://www.latex-project.org/get/), we use [Overleaf](https://www.overleaf.com/latex/templates/rgu-thesis-template-2025/jjzgwddwzmqm) to provide you with a template which you can use for all of your submissions!

# %% [markdown]
# * We also have a [Beamer (slides)](https://www.overleaf.com/read/czkwwqcwgrgk#c53123) template

# %% [markdown]
# # Travel

# %% [markdown]
# * Students **must** disclose their plans during the RSR meeting; these can be reviewed in the interim one (Feb)
#     * No record, no travel!

# %% [markdown]
# * Travel must be notified with the following **minimum** notice:
#
#     * 2–4 weeks for Aberdeen-based or no‑cost/no‑booking travel
#     * 4–6 weeks for UK travel
#     * 10–12 weeks for Overseas travel (longer if visas are required)

# %% [markdown]
# * Requests submitted one week or less before a conference registration deadline will be automatically declined unless you provide a strong justification for the delay.

# %% [markdown]
# * The admin team has created this [comprehensive SharePoint site](https://liverguac.sharepoint.com/teams/SoCET-ResearchStudents/SitePages/Travel-Funding.aspx?xsdata=...&sdata=Ykx2ZHVmNzdibXJ3VXZjWWpMc2d2TWpzbmRtbnc2bExlQXdTNWpzTkZYRT0%3D&ovuser=51a0a69c-0e4f-4b3d-b642-12e013198635%2Cc.moreno-garcia%40rgu.ac.uk&OR=Teams-HL&CT=1752677454800&clickparams=eyJBcHBOYW1lIjoiVGVhbXMtRGVza3RvcCIsIkFwcFZlcnNpb24iOiI0OS8yNTA2MTIxNjQyMSJ9) covering all aspects that you should know

# %% [markdown]
# * Main things to consider:
#     * Pre approval *first*, booking *second*
#         * Bookings **MUST** be done by the school!
#     * Keep in mind the budget limits
#         * You have a 1000 GBP/year "budget"!
#     * Don't book anything yourselves, otherwise insurance **won't** cover you and you won't be reinbursed!

# %% [markdown]
# * Your travel budget can be topped up looking for mobility grants
#     * Conferences offer them
#     * Some funding bodies give you money for that
#     * Sometimes there are calls from the aforementioned societies + the fee discounts you can get for being a member and a student

# %% [markdown]
# * Also, consider research stays as a way to move around!
#     * Trickier if you need to comply with Visa regulations, but still something to think about!

# %% [markdown]
# # When/Who/Why to Contact

# %% [markdown]
# * Director of Studies (i.e. your principal supervisor):
#     + Your PhD work
#     + Annual leave (then inform ResearchAdmin)
#     + Activity Report (your side of the story)

# %% [markdown]
# * Grad School:
#     + Forms
#     + PgCert
#     + Viva (cc'ing RDC and ResearchAdmin)

# %% [markdown]
# * RDC:
#     + Problems!
#     + Transfer Viva
#         * cc'ing assessor & ResearchAdmin
#         * once DoS agrees and docs have been submitted to the Grad School

# %% [markdown]
# # Questions?
